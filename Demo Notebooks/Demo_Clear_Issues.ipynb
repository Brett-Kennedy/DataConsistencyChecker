# %%
import pandas as pd
from sklearn.datasets import fetch_openml
import sys

sys.path.insert(0, "..")
from check_data_consistency import DataConsistencyChecker

# %%
# This notebook provides examples of clearing & restoring results.

# %%
# Load in the data

data = fetch_openml('hypothyroid', version=1)
data_df = pd.DataFrame(data.data, columns=data.feature_names)
display(data_df.head())
# Out:
#     age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0  41.0   F            f                  f                         f    f
# 1  23.0   F            f                  f                         f    f
# 2  46.0   M            f                  f                         f    f
# 3  70.0   F            t                  f                         f    f
# 4  70.0   F            f                  f                         f    f
#
#   pregnant thyroid_surgery I131_treatment query_hypothyroid  ...   T3  \
# 0        f               f              f                 f  ...  2.5
# 1        f               f              f                 f  ...  2.0
# 2        f               f              f                 f  ...  NaN
# 3        f               f              f                 f  ...  1.9
# 4        f               f              f                 f  ...  1.2
#
#   TT4_measured    TT4 T4U_measured   T4U FTI_measured    FTI  TBG_measured  \
# 0            t  125.0            t  1.14            t  109.0             f
# 1            t  102.0            f   NaN            f    NaN             f
# 2            t  109.0            t  0.91            t  120.0             f
# 3            t  175.0            f   NaN            f    NaN             f
# 4            t   61.0            t  0.87            t   70.0             f
#
#   TBG  referral_source
# 0 NaN             SVHC
# 1 NaN            other
# 2 NaN            other
# 3 NaN            other
# 4 NaN              SVI
#
# [5 rows x 29 columns]

# %%
dc = DataConsistencyChecker(verbose=0) 
dc.init_data(data_df)

# This dataset is quick to test anyway, but we specify fast_only in order 
# to reduce the results found, to make the example simpler. 
dc.check_data_quality(fast_only=True) 

# Get a view of the patterns and exceptions found
ret = dc.summarize_patterns_and_exceptions()
display(ret)
# Out:
# Data consistency check complete.
# Analysed 3,772 rows, 27 columns
# Executed 70 tests.
#
# Patterns without Exceptions:
# Found 20 patterns without exceptions
# 7 tests (10.00% of tests) identified at least one pattern without exceptions each.
# By default some patterns are not listed in calls to display_detailed_results().
#
# Patterns with Exceptions:
# Found 11 patterns with exceptions
# 5 tests (7.14% of tests) flagged at least one exception each.
# Flagged 69 row(s) with at least one exception.
# Flagged 4 column(s) with at least one exception.
#                     Test ID Number Patterns without Exceptions  \
# 0                  POSITIVE                                  6
# 1           NUMBER_DECIMALS                                  2
# 2             RARE_DECIMALS
# 3   UNUSUAL_ORDER_MAGNITUDE
# 4             FEW_NEIGHBORS
# 5                VERY_SMALL
# 6                VERY_LARGE
# 7                  NON_ZERO                                  6
# 8          GREATER_THAN_ONE                                  3
# 9          FIRST_CHAR_ALPHA                                  1
# 10    UNIQUE_VALUES_PER_ROW                                  1
# 11  NEGATIVE_VALUES_PER_ROW                                  1
#
#    Number Patterns with Exceptions
# 0
# 1
# 2                                2
# 3                                3
# 4                                1
# 5                                2
# 6                                3
# 7
# 8
# 9
# 10
# 11

# %%
# After some examination, it may be decided that the 'UNIQUE_VALUES_PER_ROW', 
# and 'NEGATIVE_VALUES_PER_ROW' tests were not relevant, or will be handled
# elsewhere, so we can clear these.

dc.clear_results(test_id_list=['UNIQUE_VALUES_PER_ROW', 'NEGATIVE_VALUES_PER_ROW'])

# Examine the new set of results with these test results removed
ret = dc.summarize_patterns_and_exceptions()
display(ret)
# Out:
#                    Test ID Number Patterns without Exceptions  \
# 0                 POSITIVE                                  6
# 1          NUMBER_DECIMALS                                  2
# 2            RARE_DECIMALS
# 3  UNUSUAL_ORDER_MAGNITUDE
# 4            FEW_NEIGHBORS
# 5               VERY_SMALL
# 6               VERY_LARGE
# 7                 NON_ZERO                                  6
# 8         GREATER_THAN_ONE                                  3
# 9         FIRST_CHAR_ALPHA                                  1
#
#   Number Patterns with Exceptions
# 0
# 1
# 2                               2
# 3                               3
# 4                               1
# 5                               2
# 6                               3
# 7
# 8
# 9

# %%
# Calling summarize_patterns_by_test_and_feature(), we
# can see which features were involved with the results.

ret = dc.summarize_patterns_by_test_and_feature()
display(ret)
# Out:
#                  age sex on_thyroxine query_on_thyroxine  \
# Test ID
# POSITIVE           ✔
# NUMBER_DECIMALS
# NON_ZERO           ✔
# GREATER_THAN_ONE   ✔
# FIRST_CHAR_ALPHA
#
#                  on_antithyroid_medication sick pregnant thyroid_surgery  \
# Test ID
# POSITIVE
# NUMBER_DECIMALS
# NON_ZERO
# GREATER_THAN_ONE
# FIRST_CHAR_ALPHA
#
#                  I131_treatment query_hypothyroid  ... TSH T3_measured T3  \
# Test ID                                            ...
# POSITIVE                                           ...   ✔              ✔
# NUMBER_DECIMALS                                    ...                  ✔
# NON_ZERO                                           ...   ✔              ✔
# GREATER_THAN_ONE                                   ...
# FIRST_CHAR_ALPHA                                   ...
#
#                  TT4_measured TT4 T4U_measured T4U FTI_measured FTI  \
# Test ID
# POSITIVE                        ✔                ✔                ✔
# NUMBER_DECIMALS                                  ✔
# NON_ZERO                        ✔                ✔                ✔
# GREATER_THAN_ONE                ✔                                 ✔
# FIRST_CHAR_ALPHA
#
#                  referral_source
# Test ID
# POSITIVE
# NUMBER_DECIMALS
# NON_ZERO
# GREATER_THAN_ONE
# FIRST_CHAR_ALPHA               ✔
#
# [5 rows x 27 columns]

# %%
# We may determine that the results related to 2 columns may be cleared. 

dc.clear_results(col_name_list=['T4U_measured', 'age'])

# Examine the set of features for each pattern again with these removed. 
ret = dc.summarize_patterns_by_test_and_feature()
display(ret)
# Out:
#                  age sex on_thyroxine query_on_thyroxine  \
# Test ID
# POSITIVE
# NUMBER_DECIMALS
# NON_ZERO
# GREATER_THAN_ONE
# FIRST_CHAR_ALPHA
#
#                  on_antithyroid_medication sick pregnant thyroid_surgery  \
# Test ID
# POSITIVE
# NUMBER_DECIMALS
# NON_ZERO
# GREATER_THAN_ONE
# FIRST_CHAR_ALPHA
#
#                  I131_treatment query_hypothyroid  ... TSH T3_measured T3  \
# Test ID                                            ...
# POSITIVE                                           ...   ✔              ✔
# NUMBER_DECIMALS                                    ...                  ✔
# NON_ZERO                                           ...   ✔              ✔
# GREATER_THAN_ONE                                   ...
# FIRST_CHAR_ALPHA                                   ...
#
#                  TT4_measured TT4 T4U_measured T4U FTI_measured FTI  \
# Test ID
# POSITIVE                        ✔                ✔                ✔
# NUMBER_DECIMALS                                  ✔
# NON_ZERO                        ✔                ✔                ✔
# GREATER_THAN_ONE                ✔                                 ✔
# FIRST_CHAR_ALPHA
#
#                  referral_source
# Test ID
# POSITIVE
# NUMBER_DECIMALS
# NON_ZERO
# GREATER_THAN_ONE
# FIRST_CHAR_ALPHA               ✔
#
# [5 rows x 27 columns]

# %%
# We can look at the exceptions as well. Calling get_exceptions_summary(),
# we get a list of the issues found.

ret = dc.get_exceptions_list()
display(ret)
# Out:
#                     Test ID Column(s)  \
# 0             RARE_DECIMALS       TT4
# 1             RARE_DECIMALS       FTI
# 3   UNUSUAL_ORDER_MAGNITUDE       TT4
# 4   UNUSUAL_ORDER_MAGNITUDE       FTI
# 5             FEW_NEIGHBORS       TT4
# 6                VERY_SMALL       T4U
# 7                VERY_SMALL       FTI
# 9                VERY_LARGE       TT4
# 10               VERY_LARGE       T4U
#
#                                Description of Pattern  Number of Exceptions  \
# 0   The column consistently contains values with o...                     5
# 1   The column consistently contains values with o...                     7
# 3   This test checks for values of an unusual orde...                     7
# 4   This test checks for values of an unusual orde...                     8
# 5   The test marked any values more than 42.800 aw...                     1
# 6   The test marked any values less than 0.3800000...                     4
# 7   The test marked any values less than 10.0 as v...                    17
# 9   The test marked any values larger than 250.00 ...                    17
# 10  The test marked any values larger than 1.78 as...                    17
#
#     Issue ID
# 0          0
# 1          1
# 3          3
# 4          4
# 5          5
# 6          6
# 7          7
# 9          9
# 10        10

# %%
# We may determine that issues 3 and 4 may be cleared.

dc.clear_results(issue_id_list=[3, 4])

# Examine the results with these two issues removed. 
ret = dc.get_exceptions_list()
display(ret)
# Out:
#           Test ID Column(s)  \
# 0   RARE_DECIMALS       TT4
# 1   RARE_DECIMALS       FTI
# 5   FEW_NEIGHBORS       TT4
# 6      VERY_SMALL       T4U
# 7      VERY_SMALL       FTI
# 9      VERY_LARGE       TT4
# 10     VERY_LARGE       T4U
#
#                                Description of Pattern  Number of Exceptions  \
# 0   The column consistently contains values with o...                     5
# 1   The column consistently contains values with o...                     7
# 5   The test marked any values more than 42.800 aw...                     1
# 6   The test marked any values less than 0.3800000...                     4
# 7   The test marked any values less than 10.0 as v...                    17
# 9   The test marked any values larger than 250.00 ...                    17
# 10  The test marked any values larger than 1.78 as...                    17
#
#     Issue ID
# 0          0
# 1          1
# 5          5
# 6          6
# 7          7
# 9          9
# 10        10

# %%
# Again call summarize_patterns_and_exceptions() to see what is remaining. 

ret = dc.summarize_patterns_and_exceptions()
display(ret)
# Out:
#             Test ID Number Patterns without Exceptions  \
# 0          POSITIVE                                  5
# 1   NUMBER_DECIMALS                                  2
# 2     RARE_DECIMALS
# 3     FEW_NEIGHBORS
# 4        VERY_SMALL
# 5        VERY_LARGE
# 6          NON_ZERO                                  5
# 7  GREATER_THAN_ONE                                  2
# 8  FIRST_CHAR_ALPHA                                  1
#
#   Number Patterns with Exceptions
# 0
# 1
# 2                               2
# 3                               1
# 4                               2
# 5                               2
# 6
# 7
# 8

# %%
# We may choose to clear all patterns and leave only the exceptions. 

dc.clear_results(clear_all_patterns=True)

# Examine the remaining results. 
ret = dc.summarize_patterns_and_exceptions()
display(ret)
# Out:
#          Test ID Number Patterns without Exceptions  \
# 0  RARE_DECIMALS
# 1  FEW_NEIGHBORS
# 2     VERY_SMALL
# 3     VERY_LARGE
#
#    Number Patterns with Exceptions
# 0                                2
# 1                                1
# 2                                2
# 3                                2

# %%
# Calling restore_results() will restore the state after the last call
# to check_data_quality()

dc.restore_results()

ret = dc.summarize_patterns_and_exceptions()
display(ret)
# Out:
#                     Test ID Number Patterns without Exceptions  \
# 0                  POSITIVE                                  6
# 1           NUMBER_DECIMALS                                  2
# 2             RARE_DECIMALS
# 3   UNUSUAL_ORDER_MAGNITUDE
# 4             FEW_NEIGHBORS
# 5                VERY_SMALL
# 6                VERY_LARGE
# 7                  NON_ZERO                                  6
# 8          GREATER_THAN_ONE                                  3
# 9          FIRST_CHAR_ALPHA                                  1
# 10    UNIQUE_VALUES_PER_ROW                                  1
# 11  NEGATIVE_VALUES_PER_ROW                                  1
#
#    Number Patterns with Exceptions
# 0
# 1
# 2                                2
# 3                                3
# 4                                1
# 5                                2
# 6                                3
# 7
# 8
# 9
# 10
# 11
